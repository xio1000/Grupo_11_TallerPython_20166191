# %% [markdown]
# <a href="https://colab.research.google.com/github/xio1000/Grupo_11_TallerPython_20166191/blob/main/GRUPO_11_TAREA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_ciudades = {
    'Ciudad': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'],
    'Habitantes': [1047996, 1000169, 92331, 428450, 305717, 484475, 441649, 385098, 294395, 283734],
    'Area_km2': [2672.28, 1545.77, 1487.7, 116.5, 279.89, 6217.26, 368.9, 109.19, 59.4, 483.44],
    'Altitud_m': [154, 2325, 34, 3399, 29, 29, 106, 3271, 562, 156],
    'Densidad_poblacion_por_km2': [3924, 64.8, 62.1, 3673, 1091.6, 77.9, 1196, 3528.6, 4966, 587.2]}


nfos = pd.DataFrame(data_ciudades)
nfos
# Out:
#      Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2
# 0      Lima     1047996   2672.28        154                      3924.0
# 1  Arequipa     1000169   1545.77       2325                        64.8
# 2  Trujillo       92331   1487.70         34                        62.1
# 3     Cusco      428450    116.50       3399                      3673.0
# 4  Chiclayo      305717    279.89         29                      1091.6
# 5     Piura      484475   6217.26         29                        77.9
# 6   Iquitos      441649    368.90        106                      1196.0
# 7  Huancayo      385098    109.19       3271                      3528.6
# 8     Tacna      294395     59.40        562                      4966.0
# 9  Pucallpa      283734    483.44        156                       587.2

# %%
data_ciudades_2 = {
    'Ciudad': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Iquitos', 'Huancayo', 'Tacna', 'Pucallpa'],
    'Gentilicio': ['Limeño', 'Arequipeño', 'Trujillano', 'Cusqueño', 'Chiclayano', 'Piurano', 'Iquiteño', 'Huancaino', 'Tacneño', 'Pucallpino'],
    'Provincia': ['Lima', 'Arequipa', 'Trujillo', 'Cusco', 'Chiclayo', 'Piura', 'Maynas', 'Huancayo', 'Tacna', 'Coronel Portillo'],
    'Region': ['Lima', 'Arequipa', 'La Libertad', 'Cusco', 'Lambayeque', 'Piura', 'Loreto', 'Junín', 'Tacna', 'Ucayali']
}


nombres = pd.DataFrame(data_ciudades_2)

# Mostrar
nombres
# Out:
#      Ciudad  Gentilicio         Provincia       Region
# 0      Lima     Limeño              Lima         Lima
# 1  Arequipa  Arequipeño          Arequipa     Arequipa
# 2  Trujillo  Trujillano          Trujillo  La Libertad
# 3     Cusco    Cusqueño             Cusco        Cusco
# 4  Chiclayo  Chiclayano          Chiclayo   Lambayeque
# 5     Piura     Piurano             Piura        Piura
# 6   Iquitos    Iquiteño            Maynas       Loreto
# 7  Huancayo   Huancaino          Huancayo        Junín
# 8     Tacna     Tacneño             Tacna        Tacna
# 9  Pucallpa  Pucallpino  Coronel Portillo      Ucayali

# %%
cuadro_completo = pd.merge(nfos, nombres, on='Ciudad', how='inner')

# Mostramos
cuadro_completo
# Out:
#      Ciudad  Habitantes  Area_km2  Altitud_m  Densidad_poblacion_por_km2  \
# 0      Lima     1047996   2672.28        154                      3924.0
# 1  Arequipa     1000169   1545.77       2325                        64.8
# 2  Trujillo       92331   1487.70         34                        62.1
# 3     Cusco      428450    116.50       3399                      3673.0
# 4  Chiclayo      305717    279.89         29                      1091.6
# 5     Piura      484475   6217.26         29                        77.9
# 6   Iquitos      441649    368.90        106                      1196.0
# 7  Huancayo      385098    109.19       3271                      3528.6
# 8     Tacna      294395     59.40        562                      4966.0
# 9  Pucallpa      283734    483.44        156                       587.2
#
#    Gentilicio         Provincia       Region
# 0     Limeño              Lima         Lima
# 1  Arequipeño          Arequipa     Arequipa
# 2  Trujillano          Trujillo  La Libertad
# 3    Cusqueño             Cusco        Cusco
# 4  Chiclayano          Chiclayo   Lambayeque
# 5     Piurano             Piura        Piura
# 6    Iquiteño            Maynas       Loreto
# 7   Huancaino          Huancayo        Junín
# 8     Tacneño             Tacna        Tacna
# 9  Pucallpino  Coronel Portillo      Ucayali

# %%
# Estadísticas descriptivas del DataFrame
descripcion = cuadro_completo.describe()

# Summary
print(descripcion)

min_densidad = cuadro_completo['Densidad_poblacion_por_km2'].min()
max_densidad = cuadro_completo['Densidad_poblacion_por_km2'].max()

ciudad_min_densidad = cuadro_completo[cuadro_completo['Densidad_poblacion_por_km2'] == min_densidad]['Ciudad'].values[0]
ciudad_max_densidad = cuadro_completo[cuadro_completo['Densidad_poblacion_por_km2'] == max_densidad]['Ciudad'].values[0]

# Results
print(f"La mínima densidad poblacional es {min_densidad} y corresponde a la ciudad de {ciudad_min_densidad}.")
print(f"La máxima densidad poblacional es {max_densidad} y corresponde a la ciudad de {ciudad_max_densidad}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-be396fece9d9> in <cell line: 2>()
#       1 # Estadísticas descriptivas del DataFrame
# ----> 2 descripcion = cuadro_completo.describe()
#       3
#       4 # Summary
#       5 print(descripcion)
#
# NameError: name 'cuadro_completo' is not defined

# %%
import matplotlib.pyplot as plt

cuadro_completo = pd.merge(nfos, nombres, on='Ciudad', how='inner')

plt.figure(figsize=(12, 6))
plt.bar(cuadro_completo['Ciudad'], cuadro_completo['Habitantes'], color='skyblue')
plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Habitantes')
plt.title('Cantidad de Habitantes en Cada Ciudad')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar
plt.show()

# %%
#GRAFICO DISPERSION
plt.figure(figsize=(10, 6))
plt.scatter(cuadro_completo['Altitud_m'], cuadro_completo['Habitantes'], color='coral', edgecolor='black')
plt.xlabel('Altitud (m)')
plt.ylabel('Número de Habitantes')
plt.title('Gráfico de Dispersión entre Altitud y Número de Habitantes')
plt.grid(True)


plt.show()
